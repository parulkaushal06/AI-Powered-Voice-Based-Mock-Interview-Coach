# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sb

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\Lenovo\Desktop\Agai Project\notebooks

# %%
import os
os.chdir("..")   # moves up one level, from notebooks/ to project root
print(os.getcwd())  # confirm it's now your project root
# Out:
# c:\Users\Lenovo\Desktop\Agai Project

# %%
folders = [
    "data/raw/hr_questions",
    "data/raw/technical_questions",
    "data/raw/resumes",
    "data/raw/job_descriptions",
    "data/raw/resume_jd_pairs"
]

for folder in folders:
    print(f"\n📁 {folder}")
    if os.path.exists(folder):
        for f in os.listdir(folder):
            print("   -", f)
    else:
        print("   ⚠️ folder not found")
# Out:
# 📁 data/raw/hr_questions
#    - hr_interview_questions_dataset.json
#
# 📁 data/raw/technical_questions
#    - Software Questions.csv
#
# 📁 data/raw/resumes
#    - resume_data.csv
#    - sample.json
#    - train.json
#
# 📁 data/raw/job_descriptions
#    - data.csv
#    - job_title_des.csv
#
# 📁 data/raw/resume_jd_pairs
#    - Resume.csv
#    - training_data.csv

# %%
hr_df = pd.read_json("data/raw/hr_questions/hr_interview_questions_dataset.json")
print(hr_df.shape)
print(hr_df.columns)
hr_df.head()
# Out:
# (2500000, 8)
# Index(['question', 'category', 'role', 'experience', 'difficulty',
#        'source_type', 'ideal_answer', 'keywords'],
#       dtype='object')
#                                             question             category  \
# 0  Tell me about a time you had to learn somethin...         Adaptability
# 1  Describe a time you handled a difficult situat...  Conflict Resolution
# 2              Where do you see yourself in 5 years?         Career Goals
# 3  Tell me about a conflict you had with a cowork...  Conflict Resolution
# 4  What skills do you hope to develop in your nex...         Career Goals
#
#                   role experience difficulty  source_type  \
# 0      DevOps Engineer    fresher       Easy   Open-Ended
# 1      Product Manager    2 years       Hard   Behavioral
# 2       Data Scientist    2 years     Medium   Open-Ended
# 3  Marketing Associate    4 years       Hard   STAR-Based
# 4  Marketing Associate     1 year       Easy  Situational
#
#                                         ideal_answer              keywords
# 0  I'm always eager to learn and embrace change a...    [flexible, change]
# 1  When faced with conflict, I approach it calmly...   [problem, disagree]
# 2  My long-term goal is to grow into a senior rol...   [aspiration, dream]
# 3  When faced with conflict, I approach it calmly...   [problem, disagree]
# 4  My long-term goal is to grow into a senior rol...  [future, aspiration]

# %%
tech_df = pd.read_csv("data/raw/technical_questions/Software Questions.csv", encoding="latin1")
print(tech_df.shape)
print(tech_df.columns)
tech_df.head()
# Out:
# (200, 5)
# Index(['Question Number', 'Question', 'Answer', 'Category', 'Difficulty'], dtype='object')
#    Question Number                                           Question  \
# 0                1  What is the difference between compilation and...
# 1                2               Explain the concept of polymorphism.
# 2                3          Define encapsulation and give an example.
# 3                4  What is an abstract class, and how is it diffe...
# 4                5  Describe the principles of Object-Oriented Pro...
#
#                                               Answer             Category  \
# 0  Compilation translates source code into machin...  General Programming
# 1  Polymorphism allows objects of different class...  General Programming
# 2  Encapsulation bundles data and methods in a cl...  General Programming
# 3  An abstract class can't be instantiated and ca...  General Programming
# 4  OOP principles include encapsulation, inherita...  General Programming
#
#   Difficulty
# 0     Medium
# 1     Medium
# 2       Hard
# 3     Medium
# 4     Medium

# %%
resume_df = pd.read_csv("data/raw/resumes/resume_data.csv")
print(resume_df.shape)
print(resume_df.columns)
resume_df.head()
# Out:
# (9544, 35)
# Index(['address', 'career_objective', 'skills', 'educational_institution_name',
#        'degree_names', 'passing_years', 'educational_results', 'result_types',
#        'major_field_of_studies', 'professional_company_names', 'company_urls',
#        'start_dates', 'end_dates', 'related_skils_in_job', 'positions',
#        'locations', 'responsibilities', 'extra_curricular_activity_types',
#        'extra_curricular_organization_names',
#        'extra_curricular_organization_links', 'role_positions', 'languages',
#        'proficiency_levels', 'certification_providers', 'certification_skills',
#        'online_links', 'issue_dates', 'expiry_dates', '﻿job_position_name',
#        'educationaL_requirements', 'experiencere_requirement',
#        'age_requirement', 'responsibilities.1', 'skills_required',
#        'matched_score'],
#       dtype='object')
#   address                                   career_objective  \
# 0     NaN  Big data analytics working and database wareho...
# 1     NaN  Fresher looking to join as a data analyst and ...
# 2     NaN                                                NaN
# 3     NaN  To obtain a position in a fast-paced business ...
# 4     NaN  Professional accountant with an outstanding wo...
#
#                                               skills  \
# 0  ['Big Data', 'Hadoop', 'Hive', 'Python', 'Mapr...
# 1  ['Data Analysis', 'Data Analytics', 'Business ...
# 2  ['Software Development', 'Machine Learning', '...
# 3  ['accounts payables', 'accounts receivables', ...
# 4  ['Analytical reasoning', 'Compliance testing k...
#
#                         educational_institution_name  \
# 0  ['The Amity School of Engineering & Technology...
# 1  ['Delhi University - Hansraj College', 'Delhi ...
# 2    ['Birla Institute of Technology (BIT), Ranchi']
# 3  ['Martinez Adult Education, Business Training ...
# 4                          ['Kent State University']
#
#                                         degree_names     passing_years  \
# 0                                         ['B.Tech']          ['2019']
# 1    ['B.Sc (Maths)', 'M.Sc (Science) (Statistics)']  ['2015', '2018']
# 2                                         ['B.Tech']          ['2018']
# 3  ['Computer Applications Specialist Certificate...          ['2008']
# 4            ['Bachelor of Business Administration']            [None]
#
#   educational_results    result_types             major_field_of_studies  \
# 0             ['N/A']          [None]                    ['Electronics']
# 1      ['N/A', 'N/A']  ['N/A', 'N/A']      ['Mathematics', 'Statistics']
# 2             ['N/A']         ['N/A']  ['Electronics/Telecommunication']
# 3              [None]          [None]          ['Computer Applications']
# 4            ['3.84']          [None]                     ['Accounting']
#
#                           professional_company_names  ... online_links  \
# 0                                      ['Coca-COla']  ...          NaN
# 1                                ['BIB Consultancy']  ...          NaN
# 2                              ['Axis Bank Limited']  ...          NaN
# 3  ['Company Name ï¼ City , State', 'Company Name...  ...          NaN
# 4  ['Company Name', 'Company Name', 'Company Name...  ...       [None]
#
#   issue_dates           expiry_dates  \
# 0         NaN                    NaN
# 1         NaN                    NaN
# 2         NaN                    NaN
# 3         NaN                    NaN
# 4      [None]  ['February 15, 2021']
#
#                                   ﻿job_position_name  \
# 0                           Senior Software Engineer
# 1                     Machine Learning (ML) Engineer
# 2  Executive/ Senior Executive- Trade Marketing, ...
# 3                     Business Development Executive
# 4                                Senior iOS Engineer
#
#                             educationaL_requirements experiencere_requirement  \
# 0  B.Sc in Computer Science & Engineering from a ...          At least 1 year
# 1  M.Sc in Computer Science & Engineering or in a...       At least 5 year(s)
# 2            Master of Business Administration (MBA)         At least 3 years
# 3                                    Bachelor/Honors             1 to 3 years
# 4      Bachelor of Science (BSc) in Computer Science         At least 4 years
#
#       age_requirement                                 responsibilities.1  \
# 0                 NaN  Technical Support\r\nTroubleshooting\r\nCollab...
# 1                 NaN  Machine Learning Leadership\r\nCross-Functiona...
# 2                 NaN  Trade Marketing Executive\r\nBrand Visibility,...
# 3  Age 22 to 30 years  Apparel Sourcing\r\nQuality Garment Sourcing\r...
# 4                 NaN  iOS Lifecycle\r\nRequirement Analysis\r\nNativ...
#
#                                      skills_required matched_score
# 0                                                NaN      0.850000
# 1                                                NaN      0.750000
# 2  Brand Promotion\r\nCampaign Management\r\nFiel...      0.416667
# 3  Fast typing skill\r\nIELTSInternet browsing & ...      0.760000
# 4  iOS\r\niOS App Developer\r\niOS Application De...      0.650000
#
# [5 rows x 35 columns]

# %%
resume_sample_df = pd.read_json("data/raw/resumes/sample.json")
print(resume_sample_df.shape)
print(resume_sample_df.columns)
resume_sample_df.head()
# Out:
# (5, 2)
# Index(['text', 'annotations'], dtype='object')
#                                                 text  \
# 0  Abhishek Jha Application Development Associate...
# 1  Afreen Jamadar Active member of IIIT Committee...
# 2  Akhil Yadav Polemaina Hyderabad, Telangana - E...
# 3  Alok Khandai Operational Analyst (SQL DBA) Eng...
# 4  Ananya Chavan lecturer - oracle tutorials  Mum...
#
#                                          annotations
# 0  [[1296, 1622, SKILL], [993, 1154, SKILL], [939...
# 1  [[104, 148, EMAIL], [743, 1141, SKILL], [729, ...
# 2  [[3542, 3550, SKILL], [3489, 3498, SKILL], [35...
# 3  [[8142, 8428, SKILL], [8052, 8094, SKILL], [80...
# 4  [[857, 860, EDUCATION], [973, 1703, SKILL], [4...

# %%
import json
import re

with open("data/raw/resumes/train.json", "r", encoding="utf-8", errors="surrogatepass") as f:
    raw_text = f.read()

# Remove unpaired/lone surrogate characters that break JSON parsing
cleaned_text = re.sub(r'[\ud800-\udfff]', '', raw_text)

data = json.loads(cleaned_text)
resume_train_df = pd.DataFrame(data)
print(resume_train_df.shape)
print(resume_train_df.columns)
resume_train_df.head()
# Out:
# (5960, 2)
# Index(['text', 'annotations'], dtype='object')
#                                                 text  \
# 0  Abhishek Jha Application Development Associate...
# 1  Afreen Jamadar Active member of IIIT Committee...
# 2  Akhil Yadav Polemaina Hyderabad, Telangana - E...
# 3  Alok Khandai Operational Analyst (SQL DBA) Eng...
# 4  Ananya Chavan lecturer - oracle tutorials  Mum...
#
#                                          annotations
# 0  [[1296, 1622, SKILL], [993, 1154, SKILL], [939...
# 1  [[104, 148, EMAIL], [743, 1141, SKILL], [729, ...
# 2  [[3542, 3550, SKILL], [3489, 3498, SKILL], [35...
# 3  [[8142, 8428, SKILL], [8052, 8094, SKILL], [80...
# 4  [[857, 860, EDUCATION], [973, 1703, SKILL], [4...

# %%
jd_data_df = pd.read_csv("data/raw/job_descriptions/data.csv")
print(jd_data_df.shape)
print(jd_data_df.columns)
jd_data_df.head()
# Out:
# (521, 2)
# Index(['Job Title', 'Description'], dtype='object')
#                                    Job Title  \
# 0                               Data Analyst
# 1                     Data Reporting Analyst
# 2             Data Analyst (Power BI/Python)
# 3                   Data & Reporting Analyst
# 4  Data Quality Analyst (Remote Opportunity)
#
#                                          Description
# 0  job overview were seeking a data analyst to tu...
# 1  about wspc wspc is a cooperative of outstandin...
# 2  data analyst power bipython employment type fu...
# 3  our company pharmerica overview the data repor...
# 4  vetsez is seeking a data quality analyst teste...

# %%
jd_title_df = pd.read_csv("data/raw/job_descriptions/job_title_des.csv")
print(jd_title_df.shape)
print(jd_title_df.columns)
jd_title_df.head()
# Out:
# (2277, 3)
# Index(['Unnamed: 0', 'Job Title', 'Job Description'], dtype='object')
#    Unnamed: 0             Job Title  \
# 0           0     Flutter Developer
# 1           1      Django Developer
# 2           2      Machine Learning
# 3           3         iOS Developer
# 4           4  Full Stack Developer
#
#                                      Job Description
# 0  We are looking for hire experts flutter develo...
# 1  PYTHON/DJANGO (Developer/Lead) - Job Code(PDJ ...
# 2  Data Scientist (Contractor)\r\n\r\nBangalore, ...
# 3  JOB DESCRIPTION:\r\n\r\nStrong framework outsi...
# 4  job responsibility full stack engineer – react...

# %%
resume_jd_df = pd.read_csv("data/raw/resume_jd_pairs/Resume.csv")
print(resume_jd_df.shape)
print(resume_jd_df.columns)
resume_jd_df.head()
# Out:
# (2484, 4)
# Index(['ID', 'Resume_str', 'Resume_html', 'Category'], dtype='object')
#          ID                                         Resume_str  \
# 0  16852973           HR ADMINISTRATOR/MARKETING ASSOCIATE\...
# 1  22323967           HR SPECIALIST, US HR OPERATIONS      ...
# 2  33176873           HR DIRECTOR       Summary      Over 2...
# 3  27018550           HR SPECIALIST       Summary    Dedica...
# 4  17812897           HR MANAGER         Skill Highlights  ...
#
#                                          Resume_html Category
# 0  <div class="fontsize fontface vmargins hmargin...       HR
# 1  <div class="fontsize fontface vmargins hmargin...       HR
# 2  <div class="fontsize fontface vmargins hmargin...       HR
# 3  <div class="fontsize fontface vmargins hmargin...       HR
# 4  <div class="fontsize fontface vmargins hmargin...       HR

# %%
training_data_df = pd.read_csv("data/raw/resume_jd_pairs/training_data.csv")
print(training_data_df.shape)
print(training_data_df.columns)
training_data_df.head()
# Out:
# (853, 5)
# Index(['company_name', 'job_description', 'position_title',
#        'description_length', 'model_response'],
#       dtype='object')
#   company_name                                    job_description  \
# 0       Google  minimum qualifications\r\nbachelors degree or ...
# 1        Apple  description\r\nas an asc you will be highly in...
# 2      Netflix  its an amazing time to be joining netflix as w...
# 3  Robert Half  description\r\n\r\nweb designers looking to ex...
# 4    TrackFive  at trackfive weve got big goals were on a miss...
#
#                               position_title  description_length  \
# 0                           Sales Specialist                2727
# 1                 Apple Solutions Consultant                 828
# 2  Licensing Coordinator - Consumer Products                3205
# 3                               Web Designer                2489
# 4                              Web Developer                3167
#
#                                       model_response
# 0   {\r\n  "Core Responsibilities": "Responsible ...
# 1   {\r\n  "Core Responsibilities": "as an asc yo...
# 2   {\r\n  "Core Responsibilities": "Help drive b...
# 3   {\r\n  "Core Responsibilities": "Designing we...
# 4   {\r\n  "Core Responsibilities": "Build and la...

# %%
print(hr_df.info())
print("\nNull values:\n", hr_df.isnull().sum())
print("\nSample rows:\n", hr_df.sample(3))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500000 entries, 0 to 2499999
# Data columns (total 8 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   question      object
#  1   category      object
#  2   role          object
#  3   experience    object
#  4   difficulty    object
#  5   source_type   object
#  6   ideal_answer  object
#  7   keywords      object
# dtypes: object(8)
# memory usage: 152.6+ MB
# None
#
# Null values:
#  question        0
# category        0
# role            0
# experience      0
# difficulty      0
# source_type     0
# ideal_answer    0
# keywords        0
# dtype: int64
#
# Sample rows:
#                                                    question  \
# 1577928         Tell me about a time you mentored someone.
# 1775746      How do you stay updated with industry trends?
# 1548132  How do you respond when a teammate isn't pulli...
#
#                     category               role experience difficulty  \
# 1577928           Leadership  Software Engineer     1 year       Hard
# 1775746         Adaptability    DevOps Engineer    3 years       Hard
# 1548132  Conflict Resolution     Data Scientist    4 years     Medium
#
#         source_type                                       ideal_answer  \
# 1577928  Behavioral  I lead by example and encourage open communica...
# 1775746  Behavioral  I'm always eager to learn and embrace change a...
# 1548132  Open-Ended  When faced with conflict, I approach it calmly...
#
#                     keywords
# 1577928       [lead, manage]
# 1775746      [new, flexible]
# 1548132  [resolve, conflict]

# %%
subset_cols = ['question', 'category', 'role', 'experience', 'difficulty', 'source_type', 'ideal_answer']
print("Duplicate rows:", hr_df.duplicated(subset=subset_cols).sum())
# Out:
# Duplicate rows: 2465440

# %%
print(type(hr_df['keywords'].iloc[0]))
print(hr_df['keywords'].iloc[0])
# Out:
# <class 'list'>
# ['flexible', 'change']

# %%
hr_df.sample(3)
print(hr_df['category'].nunique(), hr_df['category'].unique()[:20])
print(hr_df['role'].nunique(), hr_df['role'].unique()[:20])
print(hr_df['difficulty'].unique())
# Out:
# 8 ['Adaptability' 'Conflict Resolution' 'Career Goals' 'Team Collaboration'
#  'Culture Fit' 'Motivation' 'Leadership' 'Work Style']
# 8 ['DevOps Engineer' 'Product Manager' 'Data Scientist'
#  'Marketing Associate' 'Software Engineer' 'QA Analyst' 'UX Designer'
#  'HR Specialist']
# ['Easy' 'Hard' 'Medium']

# %%
print(tech_df.info())
print("\nNull values:\n", tech_df.isnull().sum())

subset_cols = tech_df.columns.tolist()  # adjust if any column has unhashable types like lists
print("\nDuplicate rows:", tech_df.duplicated(subset=subset_cols).sum())

tech_df.sample(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Question Number  200 non-null    int64
#  1   Question         200 non-null    object
#  2   Answer           200 non-null    object
#  3   Category         200 non-null    object
#  4   Difficulty       200 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 7.9+ KB
# None
#
# Null values:
#  Question Number    0
# Question           0
# Answer             0
# Category           0
# Difficulty         0
# dtype: int64
# Duplicate rows: 0
#     Question Number                                           Question  \
# 50               51     What is unit testing, and why is it important?
# 52               53                        What is regression testing?
# 95               96  How do you monitor the performance of a web ap...
#
#                                                Answer          Category  \
# 50  Unit testing evaluates individual code compone...  Software Testing
# 52  Regression testing ensures new code changes do...  Software Testing
# 95  Monitor using tools to collect and analyze dat...            DevOps
#
#    Difficulty
# 50     Medium
# 52       Easy
# 95       Hard

# %%
print(tech_df.columns)
# Out:
# Index(['Question Number', 'Question', 'Answer', 'Category', 'Difficulty'], dtype='object')

# %%
subset_cols = ['question', 'category', 'role', 'experience', 'difficulty', 'source_type', 'ideal_answer']
hr_df = hr_df.drop_duplicates(subset=subset_cols).reset_index(drop=True)
print(hr_df.shape)  # should now be ~34,560 rows
# Out:
# (34560, 8)

# %%
# Standardize hr_df
hr_clean = hr_df.rename(columns={
    "ideal_answer": "answer"
})[["question", "answer", "category", "role", "difficulty"]].copy()
hr_clean["domain"] = "HR"

# Standardize tech_df
tech_clean = tech_df.rename(columns={
    "Question": "question",
    "Answer": "answer",
    "Category": "category",
    "Difficulty": "difficulty"
})[["question", "answer", "category", "difficulty"]].copy()
tech_clean["role"] = "Software Engineer"  # tech_df has no role column, default assumption
tech_clean["domain"] = "Technical"

# Combine into one unified question bank
unified_df = pd.concat([hr_clean, tech_clean], ignore_index=True)
print(unified_df.shape)
unified_df.sample(5)
# Out:
# (34760, 6)
#                                                 question  \
# 6712    What role do you usually play in group settings?
# 12743  How do you ensure productivity when working re...
# 18175  What's the most significant change you've had ...
# 20997         Describe a time you led a project or team.
# 12295           What drives your passion for this field?
#
#                                                   answer            category  \
# 6712   I believe communication and mutual respect are...  Team Collaboration
# 12743  I follow a structured workflow and use tools l...          Work Style
# 18175  I'm always eager to learn and embrace change a...        Adaptability
# 20997  I lead by example and encourage open communica...          Leadership
# 12295  I'm motivated by challenges and the opportunit...          Motivation
#
#                       role difficulty domain
# 6712        Data Scientist       Easy     HR
# 12743          UX Designer       Hard     HR
# 18175  Marketing Associate       Easy     HR
# 20997       Data Scientist       Easy     HR
# 12295       Data Scientist       Easy     HR

# %%
print(resume_df.info())
print("\nColumns:", resume_df.columns.tolist())
print("\nNull values:\n", resume_df.isnull().sum())

# Only run duplicated() if no column contains lists/dicts (skip or use subset if it errors)
try:
    print("\nDuplicate rows:", resume_df.duplicated().sum())
except TypeError:
    print("\nSkipping duplicate check — contains unhashable columns (lists/dicts)")

print("\nSample rows:")
print(resume_df.sample(2))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9544 entries, 0 to 9543
# Data columns (total 35 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   address                              784 non-null    object
#  1   career_objective                     4740 non-null   object
#  2   skills                               9488 non-null   object
#  3   educational_institution_name         9460 non-null   object
#  4   degree_names                         9460 non-null   object
#  5   passing_years                        9460 non-null   object
#  6   educational_results                  9460 non-null   object
#  7   result_types                         9460 non-null   object
#  8   major_field_of_studies               9460 non-null   object
#  9   professional_company_names           9460 non-null   object
#  10  company_urls                         9460 non-null   object
#  11  start_dates                          9460 non-null   object
#  12  end_dates                            9460 non-null   object
#  13  related_skils_in_job                 9460 non-null   object
#  14  positions                            9460 non-null   object
#  15  locations                            9460 non-null   object
#  16  responsibilities                     9544 non-null   object
#  17  extra_curricular_activity_types      3426 non-null   object
#  18  extra_curricular_organization_names  3426 non-null   object
#  19  extra_curricular_organization_links  3426 non-null   object
#  20  role_positions                       3426 non-null   object
#  21  languages                            700 non-null    object
#  22  proficiency_levels                   700 non-null    object
#  23  certification_providers              2008 non-null   object
#  24  certification_skills                 2008 non-null   object
#  25  online_links                         2008 non-null   object
#  26  issue_dates                          2008 non-null   object
#  27  expiry_dates                         2008 non-null   object
#  28  ﻿job_position_name                   9544 non-null   object
#  29  educationaL_requirements             9544 non-null   object
#  30  experiencere_requirement             8180 non-null   object
#  31  age_requirement                      5457 non-null   object
#  32  responsibilities.1                   9544 non-null   object
#  33  skills_required                      7843 non-null   object
#  34  matched_score                        9544 non-null   float64
# dtypes: float64(1), object(34)
# memory usage: 2.5+ MB
# None
#
# Columns: ['address', 'career_objective', 'skills', 'educational_institution_name', 'degree_names', 'passing_years', 'educational_results', 'result_types', 'major_field_of_studies', 'professional_company_names', 'company_urls', 'start_dates', 'end_dates', 'related_skils_in_job', 'positions', 'locations', 'responsibilities', 'extra_curricular_activity_types', 'extra_curricular_organization_names', 'extra_curricular_organization_links', 'role_positions', 'languages', 'proficiency_levels', 'certification_providers', 'certification_skills', 'online_links', 'issue_dates', 'expiry_dates', '\ufeffjob_position_name', 'educationaL_requirements', 'experiencere_requirement', 'age_requirement', 'responsibilities.1', 'skills_required', 'matched_score']
#
# Null values:
#  address                                8760
# career_objective                       4804
# skills                                   56
# educational_institution_name             84
# degree_names                             84
# passing_years                            84
# educational_results                      84
# result_types                             84
# major_field_of_studies                   84
# professional_company_names               84
# company_urls                             84
# start_dates                              84
# end_dates                                84
# related_skils_in_job                     84
# positions                                84
# locations                                84
# responsibilities                          0
# extra_curricular_activity_types        6118
# extra_curricular_organization_names    6118
# extra_curricular_organization_links    6118
# role_positions                         6118
# languages                              8844
# proficiency_levels                     8844
# certification_providers                7536
# certification_skills                   7536
# online_links                           7536
# issue_dates                            7536
# expiry_dates                           7536
# ﻿job_position_name                        0
# educationaL_requirements                  0
# experiencere_requirement               1364
# age_requirement                        4087
# responsibilities.1                        0
# skills_required                        1701
# matched_score                             0
# dtype: int64
#
# Duplicate rows: 0
#
# Sample rows:
#      address career_objective  \
# 1600     NaN              NaN
# 3015     NaN              NaN
#
#                                                  skills  \
# 1600  ['account reconciliation', 'accounting', 'acco...
# 3015  ['Data Analytics', 'Business Analysis', 'Busin...
#
#                            educational_institution_name  \
# 1600  ['Prairie View A&M University', 'Prairie View ...
# 3015  ['A.G. PATIL INSTITUTE OF TECHNOLOGY, Solapur'...
#
#                        degree_names     passing_years educational_results  \
# 1600  ['Masters of Science', 'BBA']   ['2009', 'N/A']      ['N/A', 'N/A']
# 3015              ['B.Tech', 'M.E']  ['2017', '2019']      ['N/A', 'N/A']
#
#         result_types             major_field_of_studies  \
# 1600  ['N/A', 'N/A']       ['Accounting', 'Accounting']
# 3015  ['N/A', 'N/A']  ['Computers', 'COMPUTER SCIENCE']
#
#                             professional_company_names  ... online_links  \
# 1600  ['Company Name', 'Company Name', 'Company Name']  ...          NaN
# 3015                  ['Graphene health tech Pvt Ltd']  ...          NaN
#
#      issue_dates expiry_dates                            ﻿job_position_name  \
# 1600         NaN          NaN  Manager- Human Resource Management (HRM)\r\n
# 3015         NaN          NaN                   Project Coordinator (Civil)
#
#                                educationaL_requirements  \
# 1600  Masters degree in any discipline, Bachelor of ...
# 3015  •Bachelor of Business Administration (BBA) in ...
#
#      experiencere_requirement     age_requirement  \
# 1600             5 to 6 years  Age 25 to 40 years
# 3015            5 to 10 years  Age 30 to 40 years
#
#                                      responsibilities.1  \
# 1600  Recruitment Coordination\r\nAppointment Manage...
# 3015  Project Design\r\nData Analysis\r\nACCORD/Alli...
#
#                                         skills_required matched_score
# 1600     HRM Report\r\nHuman Resource Management\r\nNGO      0.793333
# 3015  Auto CAD 2D 3D\r\nCivil 3D\r\nCivil Constructi...      0.650000
#
# [2 rows x 35 columns]

# %%
print(resume_train_df.iloc[0])  # look at one full raw record structure
# Out:
# text           Abhishek Jha Application Development Associate...
# annotations    [[1296, 1622, SKILL], [993, 1154, SKILL], [939...
# Name: 0, dtype: object

# %%
print(resume_sample_df.info())
print("\nColumns:", resume_sample_df.columns.tolist())
print("\nNull values:\n", resume_sample_df.isnull().sum())
try:
    print("\nDuplicate rows:", resume_sample_df.duplicated().sum())
except TypeError:
    print("\nSkipping duplicate check — unhashable columns")
print("\nSample rows:")
print(resume_sample_df.sample(2))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   text         5 non-null      object
#  1   annotations  5 non-null      object
# dtypes: object(2)
# memory usage: 212.0+ bytes
# None
#
# Columns: ['text', 'annotations']
#
# Null values:
#  text           0
# annotations    0
# dtype: int64
#
# Skipping duplicate check — unhashable columns
#
# Sample rows:
#                                                 text  \
# 4  Ananya Chavan lecturer - oracle tutorials  Mum...
# 2  Akhil Yadav Polemaina Hyderabad, Telangana - E...
#
#                                          annotations
# 4  [[857, 860, EDUCATION], [973, 1703, SKILL], [4...
# 2  [[3542, 3550, SKILL], [3489, 3498, SKILL], [35...

# %%
print(resume_train_df.info())
print("\nColumns:", resume_train_df.columns.tolist())
print("\nNull values:\n", resume_train_df.isnull().sum())
try:
    print("\nDuplicate rows:", resume_train_df.duplicated().sum())
except TypeError:
    print("\nSkipping duplicate check — unhashable columns")
print("\nOne full raw record:")
print(resume_train_df.iloc[0])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5960 entries, 0 to 5959
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   text         5960 non-null   object
#  1   annotations  5960 non-null   object
# dtypes: object(2)
# memory usage: 93.3+ KB
# None
#
# Columns: ['text', 'annotations']
#
# Null values:
#  text           0
# annotations    0
# dtype: int64
#
# Skipping duplicate check — unhashable columns
#
# One full raw record:
# text           Abhishek Jha Application Development Associate...
# annotations    [[1296, 1622, SKILL], [993, 1154, SKILL], [939...
# Name: 0, dtype: object

# %%
print(jd_data_df.info())
print("\nColumns:", jd_data_df.columns.tolist())
print("\nNull values:\n", jd_data_df.isnull().sum())
try:
    print("\nDuplicate rows:", jd_data_df.duplicated().sum())
except TypeError:
    print("\nSkipping duplicate check — unhashable columns")
print("\nSample rows:")
print(jd_data_df.sample(2))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 521 entries, 0 to 520
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Job Title    521 non-null    object
#  1   Description  521 non-null    object
# dtypes: object(2)
# memory usage: 8.3+ KB
# None
#
# Columns: ['Job Title', 'Description']
#
# Null values:
#  Job Title      0
# Description    0
# dtype: int64
#
# Duplicate rows: 0
#
# Sample rows:
#                 Job Title                                        Description
# 11         Data Analyst I  about equip equip is the leading virtual, evid...
# 434  Supply Chain Analyst  overview we are splice. we believe that people...

# %%
print(jd_data_df.info())
print("\nColumns:", jd_data_df.columns.tolist())
print("\nNull values:\n", jd_data_df.isnull().sum())
try:
    print("\nDuplicate rows:", jd_data_df.duplicated().sum())
except TypeError:
    print("\nSkipping duplicate check — unhashable columns")
print("\nSample rows:")
print(jd_data_df.sample(2))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 521 entries, 0 to 520
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Job Title    521 non-null    object
#  1   Description  521 non-null    object
# dtypes: object(2)
# memory usage: 8.3+ KB
# None
#
# Columns: ['Job Title', 'Description']
#
# Null values:
#  Job Title      0
# Description    0
# dtype: int64
#
# Duplicate rows: 0
#
# Sample rows:
#                         Job Title  \
# 206  Analyst, Markets & Customers
# 360         Business Data Analyst
#
#                                            Description
# 206  squarespace is looking for an analyst to join ...
# 360  about serviceup were revolutionizing the entir...

# %%
print(resume_jd_df.info())
print("\nColumns:", resume_jd_df.columns.tolist())
print("\nNull values:\n", resume_jd_df.isnull().sum())
try:
    print("\nDuplicate rows:", resume_jd_df.duplicated().sum())
except TypeError:
    print("\nSkipping duplicate check — unhashable columns")
print("\nSample rows:")
print(resume_jd_df.sample(2))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2484 entries, 0 to 2483
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           2484 non-null   int64
#  1   Resume_str   2484 non-null   object
#  2   Resume_html  2484 non-null   object
#  3   Category     2484 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 77.8+ KB
# None
#
# Columns: ['ID', 'Resume_str', 'Resume_html', 'Category']
#
# Null values:
#  ID             0
# Resume_str     0
# Resume_html    0
# Category       0
# dtype: int64
#
# Duplicate rows: 0
#
# Sample rows:
#             ID                                         Resume_str  \
# 1922  50222417           STAFF ACCOUNTANT       Professional S...
# 605   80275976           SE BUSINESS DEVELOPMENT MANAGER      ...
#
#                                             Resume_html              Category
# 1922  <div class="fontsize fontface vmargins hmargin...            ACCOUNTANT
# 605   <div class="fontsize fontface vmargins hmargin...  BUSINESS-DEVELOPMENT

# %%
print(training_data_df.info())
print("\nColumns:", training_data_df.columns.tolist())
print("\nNull values:\n", training_data_df.isnull().sum())
try:
    print("\nDuplicate rows:", training_data_df.duplicated().sum())
except TypeError:
    print("\nSkipping duplicate check — unhashable columns")
print("\nSample rows:")
print(training_data_df.sample(2))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 853 entries, 0 to 852
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   company_name        853 non-null    object
#  1   job_description     853 non-null    object
#  2   position_title      853 non-null    object
#  3   description_length  853 non-null    int64
#  4   model_response      853 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 33.4+ KB
# None
#
# Columns: ['company_name', 'job_description', 'position_title', 'description_length', 'model_response']
#
# Null values:
#  company_name          0
# job_description       0
# position_title        0
# description_length    0
# model_response        0
# dtype: int64
#
# Duplicate rows: 0
#
# Sample rows:
#                         company_name  \
# 644  Michael Page International Inc.
# 249                           Kantar
#
#                                        job_description  \
# 644  \r\n\r\nessential qualifications \r\n candidat...
# 249  we go beyond the obvious using intelligence pa...
#
#                                position_title  description_length  \
# 644  Large Law Real Estate Associate Attorney                2293
# 249                      Ecommerce Consultant                6749
#
#                                         model_response
# 644   {\r\n  "Core Responsibilities": "Handling a w...
# 249   {\r\n  "Core Responsibilities": "Manage and d...

# %%
import json
import re

with open("data/raw/resumes/train.json", "r", encoding="utf-8", errors="surrogatepass") as f:
    lines = f.readlines()

records = []
for line in lines:
    line = line.strip()
    if not line:
        continue
    # Remove unpaired/lone surrogate characters that break JSON parsing
    cleaned_line = re.sub(r'[\ud800-\udfff]', '', line)
    try:
        records.append(json.loads(cleaned_line))
    except json.JSONDecodeError:
        continue  # skip any genuinely malformed lines

resume_train_df = pd.DataFrame(records)
print(resume_train_df.shape)
resume_train_df.head()
# Out:
# (579575, 1)
#            0
# 0      SKILL
# 1      SKILL
# 2     PERSON
# 3     PERSON
# 4  EDUCATION

# %%
import json
import re

with open("data/raw/resumes/train.json", "r", encoding="utf-8", errors="surrogatepass") as f:
    raw_text = f.read()

# Strip unpaired/lone surrogate characters from the whole file
cleaned_text = re.sub(r'[\ud800-\udfff]', '', raw_text)

data = json.loads(cleaned_text)
resume_train_df = pd.DataFrame(data)
print(resume_train_df.shape)
resume_train_df.head()
# Out:
# (5960, 2)
#                                                 text  \
# 0  Abhishek Jha Application Development Associate...
# 1  Afreen Jamadar Active member of IIIT Committee...
# 2  Akhil Yadav Polemaina Hyderabad, Telangana - E...
# 3  Alok Khandai Operational Analyst (SQL DBA) Eng...
# 4  Ananya Chavan lecturer - oracle tutorials  Mum...
#
#                                          annotations
# 0  [[1296, 1622, SKILL], [993, 1154, SKILL], [939...
# 1  [[104, 148, EMAIL], [743, 1141, SKILL], [729, ...
# 2  [[3542, 3550, SKILL], [3489, 3498, SKILL], [35...
# 3  [[8142, 8428, SKILL], [8052, 8094, SKILL], [80...
# 4  [[857, 860, EDUCATION], [973, 1703, SKILL], [4...

# %%
jd_data_df = pd.read_csv("data/raw/job_descriptions/data.csv")
jd_title_df = pd.read_csv("data/raw/job_descriptions/job_title_des.csv")

resume_jd_df = pd.read_csv("data/raw/resume_jd_pairs/Resume.csv")
training_data_df = pd.read_csv("data/raw/resume_jd_pairs/training_data.csv")

print("All datasets loaded")
# Out:
# All datasets loaded

# %%
# Fix the hidden BOM character in column names
resume_df.columns = resume_df.columns.str.replace('\ufeff', '', regex=False)
print(resume_df.columns.tolist())
# Out:
# ['address', 'career_objective', 'skills', 'educational_institution_name', 'degree_names', 'passing_years', 'educational_results', 'result_types', 'major_field_of_studies', 'professional_company_names', 'company_urls', 'start_dates', 'end_dates', 'related_skils_in_job', 'positions', 'locations', 'responsibilities', 'extra_curricular_activity_types', 'extra_curricular_organization_names', 'extra_curricular_organization_links', 'role_positions', 'languages', 'proficiency_levels', 'certification_providers', 'certification_skills', 'online_links', 'issue_dates', 'expiry_dates', 'job_position_name', 'educationaL_requirements', 'experiencere_requirement', 'age_requirement', 'responsibilities.1', 'skills_required', 'matched_score']

# %%
resume_core = resume_df[[
    'career_objective', 'skills', 'degree_names', 'major_field_of_studies',
    'professional_company_names', 'positions', 'responsibilities',
    'job_position_name', 'educationaL_requirements', 'experiencere_requirement',
    'skills_required', 'matched_score'
]].copy()

resume_core = resume_core.dropna(subset=['skills'])
print(resume_core.shape)
resume_core.sample(3)
# Out:
# (9488, 12)
#                                        career_objective  \
# 4052  I am a software developer and analyst professi...
# 3801                                                NaN
# 6322  Dedicated and focused professional who excels ...
#
#                                                  skills  \
# 4052  ['Tensorflow', 'AWS', 'Keras', 'Deep Learning'...
# 3801  ['Project Management', 'Quality Management Sys...
# 6322  ['Project coordination', 'Forward-thinking min...
#
#                  degree_names  \
# 4052           ['B.Tech(IT)']
# 3801  ['Bachelor of Science']
# 6322           ['N/A', 'N/A']
#
#                                  major_field_of_studies  \
# 4052                         ['Information Technology']
# 3801                         ['Mechanical Engineering']
# 6322  ['Graphic Design, Real Estate', 'Architectural...
#
#                              professional_company_names  \
# 4052                                 ['AT&C Solutions']
# 3801                   ['Company Name', 'Company Name']
# 6322  ['Company Name', 'Company Name', 'Company Name...
#
#                                               positions  \
# 4052                          ['Software Developer ML']
# 3801  ['Engineering Manager/Quality Manager', 'Manuf...
# 6322  ['Project Accountant', 'Assistant to Vice Pres...
#
#                                        responsibilities  \
# 4052  Application Development\r\nObject-Oriented Des...
# 3801  iOS Lifecycle\r\nRequirement Analysis\r\nNativ...
# 6322  Full Stack Development\r\nFront-end: ReactJS, ...
#
#                            job_position_name  \
# 4052                   Data Science Engineer
# 3801                     Senior iOS Engineer
# 6322  Full Stack Developer (Python,React js)
#
#                                educationaL_requirements  \
# 4052  Bachelor of Science (BSc) in Computer Science ...
# 3801      Bachelor of Science (BSc) in Computer Science
# 6322                                    Bachelor/Honors
#
#      experiencere_requirement  \
# 4052         At least 2 years
# 3801         At least 4 years
# 6322             3 to 7 years
#
#                                         skills_required  matched_score
# 4052  Business Analysis\r\nEffective communication s...       0.793333
# 3801  iOS\r\niOS App Developer\r\niOS Application De...       0.716667
# 6322                                                NaN       0.716667

# %%
def extract_entities(row):
    text = row['text']
    entities = []
    for start, end, label in row['annotations']:
        entities.append({'entity_text': text[start:end], 'label': label})
    return entities

resume_train_df['entities'] = resume_train_df.apply(extract_entities, axis=1)
print(resume_train_df.iloc[0]['entities'][:5])
# Out:
# [{'entity_text': '• Programming language: C, C++, Java • Oracle PeopleSoft • Internet Of Things • Machine Learning • Database Management System • Computer Networks • Operating System worked on: Linux, Windows, Mac  Non - Technical Skills  • Honest and Hard-Working • Tolerant and Flexible to Different Situations • Polite and Calm • Team-Player', 'label': 'SKILL'}, {'entity_text': 'C (Less than 1 year), Database (Less than 1 year), Database Management (Less than 1 year), Database Management System (Less than 1 year), Java (Less than 1 year)', 'label': 'SKILL'}, {'entity_text': 'Kendriya Vidyalaya', 'label': 'PERSON'}, {'entity_text': 'Woodbine modern school', 'label': 'PERSON'}, {'entity_text': '2017', 'label': 'EDUCATION'}]

# %%
all_labels = set()
for entities in resume_train_df['entities']:
    for e in entities:
        all_labels.add(e['label'])
print(all_labels)
# Out:
# {'OTHER', 'LOCATION', 'COLLABORATION', 'EXPERTISE', 'SKILL', 'EMAIL', 'EDUCATION', 'COMPANY', 'ACTION', 'DESIGNATION', 'PERSON', 'LANGUAGE', 'CERTIFICATION', 'EXPERIENCE'}

# %%
def extract_skills(entities):
    return list(set(e['entity_text'] for e in entities if e['label'] == 'SKILL'))

resume_train_df['extracted_skills'] = resume_train_df['entities'].apply(extract_skills)
print(resume_train_df[['text', 'extracted_skills']].iloc[0])
# Out:
# text                Abhishek Jha Application Development Associate...
# extracted_skills    [• Programming language: C, C++, Java • Oracle...
# Name: 0, dtype: object

# %%
resume_categorized = resume_jd_df[['ID', 'Resume_str', 'Category']].copy()
resume_categorized['Resume_str'] = resume_categorized['Resume_str'].str.strip()

print(resume_categorized.shape)
print(resume_categorized['Category'].nunique())
print(resume_categorized['Category'].unique())
resume_categorized.sample(2)
# Out:
# (2484, 3)
# 24
# ['HR' 'DESIGNER' 'INFORMATION-TECHNOLOGY' 'TEACHER' 'ADVOCATE'
#  'BUSINESS-DEVELOPMENT' 'HEALTHCARE' 'FITNESS' 'AGRICULTURE' 'BPO' 'SALES'
#  'CONSULTANT' 'DIGITAL-MEDIA' 'AUTOMOBILE' 'CHEF' 'FINANCE' 'APPAREL'
#  'ENGINEERING' 'ACCOUNTANT' 'CONSTRUCTION' 'PUBLIC-RELATIONS' 'BANKING'
#  'ARTS' 'AVIATION']
#             ID                                         Resume_str     Category
# 1412  21101152  EXECUTIVE CHEF         Professional Summary   ...         CHEF
# 1729  31684925  ENGINEERING ASSISTANT         Summary    Hard ...  ENGINEERING

# %%
import re

# --- Source 1: resume_df (structured) ---
def combine_text_1(row):
    parts = [str(row.get('career_objective', '')), str(row.get('responsibilities', ''))]
    return " ".join(p for p in parts if p != 'nan')

resume_1 = pd.DataFrame({
    'resume_id': resume_core.index.astype(str) + "_r1",
    'source': 'resume_df',
    'raw_text': resume_core.apply(combine_text_1, axis=1),
    'skills': resume_core['skills'],
    'category': resume_core['job_position_name']
})

# --- Source 2: resume_train_df (NER-extracted) ---
# Clean up skills — split on bullets/commas since raw spans dumped whole lines
def clean_skill_list(skills):
    cleaned = []
    for s in skills:
        parts = re.split(r'[•,]', s)
        cleaned.extend([p.strip() for p in parts if p.strip() and len(p.strip()) < 50])
    return list(set(cleaned))

resume_train_df['clean_skills'] = resume_train_df['extracted_skills'].apply(clean_skill_list)

resume_2 = pd.DataFrame({
    'resume_id': resume_train_df.index.astype(str) + "_r2",
    'source': 'resume_train_df',
    'raw_text': resume_train_df['text'],
    'skills': resume_train_df['clean_skills'],
    'category': None
})

# --- Source 3: resume_jd_df (categorized plain text) ---
resume_3 = pd.DataFrame({
    'resume_id': resume_categorized['ID'].astype(str) + "_r3",
    'source': 'resume_jd_df',
    'raw_text': resume_categorized['Resume_str'],
    'skills': None,
    'category': resume_categorized['Category']
})

# --- Merge all three ---
unified_resumes = pd.concat([resume_1, resume_2, resume_3], ignore_index=True)
print(unified_resumes.shape)
unified_resumes.sample(5)
# Out:
# (17932, 5)
#       resume_id           source  \
# 14831   5343_r2  resume_train_df
# 2260    2276_r1        resume_df
# 6350    6385_r1        resume_df
# 11596   2108_r2  resume_train_df
# 13177   3689_r2  resume_train_df
#
#                                                 raw_text  \
# 14831  Akola Maharashtra Willing to relocate to Amrav...
# 2260   Hardware & Software Installation\r\nSystem Mon...
# 6350   Digital Marketing Strategy\r\nBrand Awareness,...
# 11596  Vijay Jawre                                   ...
# 13177  ABDULLA MEEZAN BATCHA M.I\nMobile:  +91 999488...
#
#                                                   skills  \
# 14831                         [IT Operations, IT Skills]
# 2260   ['Python', 'LeetCode', 'GDB', 'GitHub', 'HTML'...
# 6350   ['Generally Accepted Accounting Principles', '...
# 11596  [Operating Systems, Business Application, Prob...
# 13177  [hardworking, English, well, Oil, Access, Sele...
#
#                            category
# 14831                          None
# 2260   Executive/ Sr. Executive -IT
# 6350              Marketing Officer
# 11596                          None
# 13177                          None

# %%
print(jd_data_df.equals(jd_title_df))
# Out:
# False

# %%
print(jd_data_df.sample(2))
print(jd_title_df.sample(2))
# Out:
#                                       Job Title  \
# 201         Data Analyst II- Patient Experience
# 405  Junior Research/Data Analyst (PT, HubZone)
#
#                                            Description
# 201  ro is a directtopatient healthcare company wit...
# 405  position summary blue sky seeks experienced bu...
#       Unnamed: 0             Job Title  \
# 940          975  JavaScript Developer
# 1537        1607  Full Stack Developer
#
#                                         Job Description
# 940   Experience: 1-2Yrs\r\n\r\nLocation: Hyderabad\...
# 1537  software development engineer full stack – ent...

# %%
print("jd_data_df shape:", jd_data_df.shape)
print("jd_data_df columns:", jd_data_df.columns.tolist())
print()
print("jd_title_df shape:", jd_title_df.shape)
print("jd_title_df columns:", jd_title_df.columns.tolist())
# Out:
# jd_data_df shape: (521, 2)
# jd_data_df columns: ['Job Title', 'Description']
#
# jd_title_df shape: (2277, 3)
# jd_title_df columns: ['Unnamed: 0', 'Job Title', 'Job Description']

# %%
# Clean jd_data_df
jd_data_clean = jd_data_df.rename(columns={
    'Job Title': 'job_title',
    'Description': 'description'
}).copy()
jd_data_clean['source'] = 'jd_data_df'

# Clean jd_title_df — drop the junk index column
jd_title_clean = jd_title_df.drop(columns=['Unnamed: 0']).rename(columns={
    'Job Title': 'job_title',
    'Job Description': 'description'
}).copy()
jd_title_clean['source'] = 'jd_title_df'

# Combine both into one JD table
jd_combined = pd.concat([jd_data_clean, jd_title_clean], ignore_index=True)
print(jd_combined.shape)
jd_combined.sample(3)
# Out:
# (2798, 3)
#                   job_title  \
# 1804  Network Administrator
# 2198          iOS Developer
# 2337  Network Administrator
#
#                                             description       source
# 1804  Your goal will be to ensure that our technolog...  jd_title_df
# 2198  Require iPhone App Developers having 3 to 7 ye...  jd_title_df
# 2337  In a constantly changing world, we work togeth...  jd_title_df

# %%
import json

def safe_parse(x):
    try:
        return json.loads(x)
    except:
        return {}

parsed = training_data_df['model_response'].apply(safe_parse)
parsed_df = pd.json_normalize(parsed)

training_clean = pd.concat([
    training_data_df[['company_name', 'position_title', 'job_description']],
    parsed_df
], axis=1)

print(training_clean.shape)
print(training_clean.columns.tolist())
training_clean.sample(2)
# Out:
# (853, 12)
# ['company_name', 'position_title', 'job_description', 'Core Responsibilities', 'Required Skills', 'Educational Requirements', 'Experience Level', 'Preferred Qualifications', 'Compensation and Benefits', 'medical specialty', 'schedule', 'license/certification']
#                                   company_name  \
# 226  National Security Agency  Fort Meade, MD
# 215   CRST Expedited - Regional Louisville, KY
#
#                                    position_title  \
# 226  Polygraph Examiner - Entry to Mid-Level (MD)
# 215                       Solo Class A CDL Driver
#
#                                        job_description  \
# 226  \r\n\r\nresponsibilities\r\nsecurity and count...
# 215  crst is hiring regional solo classa cdl driver...
#
#                                  Core Responsibilities  \
# 226  Applying principles and methods of physiologic...
# 215  Responsible for driving and delivering freight...
#
#                                        Required Skills  \
# 226  Ability to maintain polygraph examiner certifi...
# 215  Valid Class A CDL license. Acceptable CSA scor...
#
#                               Educational Requirements  \
# 226  Bachelor's degree required, master's degree pr...
# 215                                                N/A
#
#                                       Experience Level  \
# 226  0-2 years of relevant experience for entry lev...
# 215        Previous truck driving experience required.
#
#                               Preferred Qualifications  \
# 226  Degree in criminology, behavioral science, law...
# 215                                                N/A
#
#                              Compensation and Benefits medical specialty  \
# 226  Salary range based on education and experience...               NaN
# 215  Up to $0.50 per mile and sign-on bonus. Weekly...               NaN
#
#     schedule license/certification
# 226      NaN                   NaN
# 215      NaN                   NaN

# %%
# Standardize jd_combined (already has job_title, description, source)
jd_source_1 = jd_combined[['job_title', 'description', 'source']].copy()
jd_source_1['required_skills'] = None
jd_source_1['experience_level'] = None

# Standardize training_clean to match
jd_source_2 = pd.DataFrame({
    'job_title': training_clean['position_title'],
    'description': training_clean['job_description'],
    'source': 'training_data_df',
    'required_skills': training_clean['Required Skills'],
    'experience_level': training_clean['Experience Level']
})

# Merge both into one final table
unified_job_descriptions = pd.concat([jd_source_1, jd_source_2], ignore_index=True)
print(unified_job_descriptions.shape)
unified_job_descriptions.sample(3)
# Out:
# (3651, 5)
#                   job_title  \
# 2219       Machine Learning
# 2651  Network Administrator
# 3396  Development Associate
#
#                                             description            source  \
# 2219  Looking for:\r\nStrong background in Machine L...       jd_title_df
# 2651  Key skills required for the job are: n Network...       jd_title_df
# 3396  job details\r\n\r\njob location  third corp   ...  training_data_df
#
#                                         required_skills  \
# 2219                                               None
# 2651                                               None
# 3396  Bachelor's degree required, advanced degree de...
#
#                          experience_level
# 2219                                 None
# 2651                                 None
# 3396  Minimum 2 years relevant experience

# %%
import re

def remove_surrogates(x):
    if isinstance(x, list):
        return [re.sub(r'[\ud800-\udfff]', '', str(item)) for item in x]
    elif isinstance(x, str):
        return re.sub(r'[\ud800-\udfff]', '', x)
    else:
        return x

for col in ['raw_text', 'skills', 'category']:
    unified_resumes[col] = unified_resumes[col].apply(remove_surrogates)

unified_resumes.to_csv("data/processed/text/unified_resumes.csv", index=False)
unified_job_descriptions.to_csv("data/processed/text/unified_job_descriptions.csv", index=False)

print("All unified datasets saved to data/processed/text/")
# Out:
# All unified datasets saved to data/processed/text/

# %%
import re

def clean_text(text):
    if not isinstance(text, str):
        return text
    text = text.lower()
    text = re.sub(r'<.*?>', ' ', text)          # remove HTML tags
    text = re.sub(r'http\S+|www\S+', ' ', text) # remove URLs
    text = re.sub(r'[^a-z0-9\s.,!?\'-]', ' ', text)  # remove special chars, keep basic punctuation
    text = re.sub(r'\s+', ' ', text).strip()    # collapse extra whitespace
    return text

# %%
unified_df['question_clean'] = unified_df['question'].apply(clean_text)
unified_df['answer_clean'] = unified_df['answer'].apply(clean_text)
print(unified_df[['question', 'question_clean']].sample(3))
# Out:
#                                                 question  \
# 30405   How do you motivate others in a leadership role?
# 34747  Implement a natural language processing algori...
# 8125   Tell me about a time you had to learn somethin...
#
#                                           question_clean
# 30405   how do you motivate others in a leadership role?
# 34747  implement a natural language processing algori...
# 8125   tell me about a time you had to learn somethin...

# %%
unified_df['question_clean'] = unified_df['question'].apply(clean_text)
unified_df['answer_clean'] = unified_df['answer'].apply(clean_text)
print(unified_df[['question', 'question_clean']].sample(3))
# Out:
#                                                 question  \
# 17717          What makes a good leader in your opinion?
# 3557          How do you build trust with new teammates?
# 4142   Tell me about a conflict you had with a cowork...
#
#                                           question_clean
# 17717          what makes a good leader in your opinion?
# 3557          how do you build trust with new teammates?
# 4142   tell me about a conflict you had with a cowork...

# %%
unified_resumes['raw_text_clean'] = unified_resumes['raw_text'].apply(clean_text)
print(unified_resumes[['raw_text', 'raw_text_clean']].sample(3))
# Out:
#                                                 raw_text  \
# 16692  OPERATIONS TECHNICIAN       Summary    To obta...
# 2800   Design Review\r\nCoordination\r\nProposal Prep...
# 5486   Generative AI Development\r\nEvolutionary Comp...
#
#                                           raw_text_clean
# 16692  operations technician summary to obtain and so...
# 2800   design review coordination proposal preparatio...
# 5486   generative ai development evolutionary computa...

# %%
unified_job_descriptions['description_clean'] = unified_job_descriptions['description'].apply(clean_text)
print(unified_job_descriptions[['description', 'description_clean']].sample(3))
# Out:
#                                             description  \
# 2026  Infosys is seeking a Senior Media Developer Le...
# 574   The iOS Swift Developer will be an individual ...
# 3587  our assistants are our frontline employees and...
#
#                                       description_clean
# 2026  infosys is seeking a senior media developer le...
# 574   the ios swift developer will be an individual ...
# 3587  our assistants are our frontline employees and...

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python313\python.exe

# %%
import sys
# !{sys.executable} -m pip install nltk
# Out:
# Collecting nltk
#   Using cached nltk-3.10.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: defusedxml in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from nltk) (0.7.1)
# Collecting click (from nltk)
#   Using cached click-8.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: joblib in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from nltk) (1.5.3)
# Collecting regex>=2021.8.3 (from nltk)
#   Using cached regex-2026.7.19-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Collecting tqdm (from nltk)
#   Using cached tqdm-4.70.0-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from click->nltk) (0.4.6)
# Using cached nltk-3.10.2-py3-none-any.whl (1.7 MB)
# Using cached regex-2026.7.19-cp313-cp313-win_amd64.whl (277 kB)
# Using cached click-8.4.2-py3-none-any.whl (119 kB)
# Using cached tqdm-4.70.0-py3-none-any.whl (80 kB)
# Installing collected packages: tqdm, regex, click, nltk
#
#    ---------------------------------------- 0/4 [tqdm]
#    ---------------------------------------- 0/4 [tqdm]
#    ---------------------------------------- 0/4 [tqdm]
#    ---------------------------------------- 0/4 [tqdm]
#    ---------- ----------------------------- 1/4 [regex]
#    -------------------- ------------------- 2/4 [click]
#    -------------------- ------------------- 2/4 [click]
#    -------------------- ------------------- 2/4 [click]
#    -------------------- ------------------- 2/4 [click]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ---------------------------------------- 4/4 [nltk]
#
# Successfully installed click-8.4.2 nltk-3.10.2 regex-2026.7.19 tqdm-4.70.0
# [notice] A new release of pip is available: 25.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

lemmatizer = WordNetLemmatizer()

def tokenize_lemmatize(text):
    if not isinstance(text, str) or text.strip() == '':
        return []
    tokens = word_tokenize(text)
    lemmatized = [lemmatizer.lemmatize(tok) for tok in tokens]
    return lemmatized

# %%
unified_df['question_tokens'] = unified_df['question_clean'].apply(tokenize_lemmatize)
unified_df['answer_tokens'] = unified_df['answer_clean'].apply(tokenize_lemmatize)
print(unified_df[['question_clean', 'question_tokens']].sample(2))
# Out:
#                                     question_clean  \
# 29263  what are your long-term career aspirations?
# 30436    how do you align with our company values?
#
#                                          question_tokens
# 29263  [what, are, your, long-term, career, aspiratio...
# 30436  [how, do, you, align, with, our, company, valu...

# %%
unified_resumes['raw_text_tokens'] = unified_resumes['raw_text_clean'].apply(tokenize_lemmatize)
print(unified_resumes[['raw_text_clean', 'raw_text_tokens']].sample(2))
# Out:
#                                           raw_text_clean  \
# 1610   relationship building hr collaboration policy ...
# 11867  curriculum vitae shaik kalesha vali present lo...
#
#                                          raw_text_tokens
# 1610   [relationship, building, hr, collaboration, po...
# 11867  [curriculum, vitae, shaik, kalesha, vali, pres...

# %%
unified_job_descriptions['description_tokens'] = unified_job_descriptions['description_clean'].apply(tokenize_lemmatize)
print(unified_job_descriptions[['description_clean', 'description_tokens']].sample(2))
# Out:
#                                       description_clean  \
# 1927  job descriptionconfiguration and troubleshooti...
# 2970  no experience requited hiring immediately appy...
#
#                                      description_tokens
# 1927  [job, descriptionconfiguration, and, troublesh...
# 2970  [no, experience, requited, hiring, immediately...

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')

stop_words = set(stopwords.words('english'))

def remove_stopwords(tokens):
    return [tok for tok in tokens if tok.lower() not in stop_words and tok.isalpha()]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %%
unified_df['question_keywords'] = unified_df['question_tokens'].apply(remove_stopwords)
unified_resumes['raw_text_keywords'] = unified_resumes['raw_text_tokens'].apply(remove_stopwords)
unified_job_descriptions['description_keywords'] = unified_job_descriptions['description_tokens'].apply(remove_stopwords)

print(unified_df[['question_tokens', 'question_keywords']].sample(2))
# Out:
#                                          question_tokens  \
# 17242  [what, motivates, you, to, come, to, work, eve...
# 28710  [how, do, you, build, trust, with, new, teamma...
#
#                          question_keywords
# 17242  [motivates, come, work, every, day]
# 28710        [build, trust, new, teammate]

# %%
category_counts = unified_df['category'].value_counts()
print(category_counts)
print("\nCategories with only 1 row:", (category_counts == 1).sum())
# Out:
# category
# Adaptability                4320
# Conflict Resolution         4320
# Career Goals                4320
# Team Collaboration          4320
# Culture Fit                 4320
# Motivation                  4320
# Leadership                  4320
# Work Style                  4320
# System Design                 24
# DevOps                        21
# Front-end                     17
# Back-end                      14
# Security                      13
# Data Structures               11
# Languages and Frameworks      10
# Version Control               10
# Web Development               10
# Database and SQL              10
# Software Testing              10
# Algorithms                    10
# General Programming            9
# Full-stack                     8
# Distributed Systems            5
# Machine Learning               5
# Low-level Systems              3
# Networking                     3
# Database Systems               3
# Data Engineering               2
# General Program                1
# Artificial Intelligence        1
# Name: count, dtype: int64
#
# Categories with only 1 row: 2

# %%
category_counts = unified_df['category'].value_counts()
rare_categories = category_counts[category_counts < 10].index.tolist()

unified_df['category_grouped'] = unified_df['category'].apply(
    lambda x: 'Other' if x in rare_categories else x
)

print(unified_df['category_grouped'].value_counts())
# Out:
# category_grouped
# Adaptability                4320
# Conflict Resolution         4320
# Career Goals                4320
# Team Collaboration          4320
# Culture Fit                 4320
# Motivation                  4320
# Leadership                  4320
# Work Style                  4320
# Other                         40
# System Design                 24
# DevOps                        21
# Front-end                     17
# Back-end                      14
# Security                      13
# Data Structures               11
# Languages and Frameworks      10
# Database and SQL              10
# Web Development               10
# Version Control               10
# Software Testing              10
# Algorithms                    10
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

train_df, temp_df = train_test_split(
    unified_df, test_size=0.30, stratify=unified_df['category_grouped'], random_state=42
)

val_df, test_df = train_test_split(
    temp_df, test_size=0.50, stratify=temp_df['category_grouped'], random_state=42
)

print("Train:", train_df.shape)
print("Val:", val_df.shape)
print("Test:", test_df.shape)
# Out:
# Train: (24332, 12)
# Val: (5214, 12)
# Test: (5214, 12)

# %%
train_df.to_csv("data/processed/text/train.csv", index=False)
val_df.to_csv("data/processed/text/val.csv", index=False)
test_df.to_csv("data/processed/text/test.csv", index=False)

print("Train/val/test splits saved")
# Out:
# Train/val/test splits saved

# %%
import sys
# !{sys.executable} -m pip install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.7.0-py3-none-any.whl.metadata (18 kB)
# Collecting transformers<6.0.0,>=4.41.0 (from sentence-transformers)
#   Downloading transformers-5.15.0-py3-none-any.whl.metadata (32 kB)
# Collecting tokenizers>=0.19 (from sentence-transformers)
#   Downloading tokenizers-0.23.1-cp310-abi3-win_amd64.whl.metadata (10 kB)
# Collecting huggingface-hub>=0.23.0 (from sentence-transformers)
#   Downloading huggingface_hub-1.27.0-py3-none-any.whl.metadata (16 kB)
# Collecting torch>=1.11.0 (from sentence-transformers)
#   Downloading torch-2.13.0-cp313-cp313-win_amd64.whl.metadata (39 kB)
# Requirement already satisfied: numpy>=1.20.0 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from sentence-transformers) (2.3.1)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from sentence-transformers) (1.16.2)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm>=4.0.0 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from sentence-transformers) (4.70.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: regex>=2025.10.22 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.7.19)
# Collecting tokenizers>=0.19 (from sentence-transformers)
#   Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Collecting typer (from transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Downloading typer-0.27.1-py3-none-any.whl.metadata (16 kB)
# Collecting safetensors>=0.8.0 (from transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Downloading safetensors-0.8.0-cp310-abi3-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (8.4.2)
# Collecting filelock>=3.10.0 (from huggingface-hub>=0.23.0->sentence-transformers)
#   Downloading filelock-3.32.2-py3-none-any.whl.metadata (2.0 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub>=0.23.0->sentence-transformers)
#   Downloading fsspec-2026.7.0-py3-none-any.whl.metadata (10 kB)
# Collecting hf-xet<2.0.0,>=1.5.2 (from huggingface-hub>=0.23.0->sentence-transformers)
#   Downloading hf_xet-1.6.0-cp38-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: colorama in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from click<9.0.0,>=8.4.2->huggingface-hub>=0.23.0->sentence-transformers) (0.4.6)
# Requirement already satisfied: anyio in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (4.9.0)
# Requirement already satisfied: certifi in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: setuptools>=77.0.3 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.11.0->sentence-transformers) (80.9.0)
# Collecting sympy>=1.13.3 (from torch>=1.11.0->sentence-transformers)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch>=1.11.0->sentence-transformers)
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: jinja2 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: sniffio>=1.1 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Collecting shellingham>=1.3.0 (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=13.8.0 (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Using cached rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting annotated-doc>=0.0.2 (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Using cached annotated_doc-0.0.5-py3-none-any.whl.metadata (6.5 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Using cached markdown_it_py-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading sentence_transformers-5.7.0-py3-none-any.whl (611 kB)
#    ---------------------------------------- 0.0/611.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/611.3 kB ? eta -:--:--
#    ----------------- ---------------------- 262.1/611.3 kB ? eta -:--:--
#    -------------------------------- ----- 524.3/611.3 kB 997.7 kB/s eta 0:00:01
#    -------------------------------------- 611.3/611.3 kB 987.8 kB/s eta 0:00:00
# Downloading transformers-5.15.0-py3-none-any.whl (11.7 MB)
#    ---------------------------------------- 0.0/11.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.7 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.7 MB 1.1 MB/s eta 0:00:10
#    -- ------------------------------------- 0.8/11.7 MB 1.2 MB/s eta 0:00:10
#    --- ------------------------------------ 1.0/11.7 MB 1.2 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.3/11.7 MB 1.2 MB/s eta 0:00:09
#    ------ --------------------------------- 1.8/11.7 MB 1.3 MB/s eta 0:00:08
#    ------- -------------------------------- 2.1/11.7 MB 1.3 MB/s eta 0:00:08
#    -------- ------------------------------- 2.4/11.7 MB 1.4 MB/s eta 0:00:07
#    --------- ------------------------------ 2.9/11.7 MB 1.4 MB/s eta 0:00:07
#    ---------- ----------------------------- 3.1/11.7 MB 1.4 MB/s eta 0:00:07
#    ----------- ---------------------------- 3.4/11.7 MB 1.5 MB/s eta 0:00:06
#    ------------- -------------------------- 3.9/11.7 MB 1.5 MB/s eta 0:00:06
#    -------------- ------------------------- 4.2/11.7 MB 1.5 MB/s eta 0:00:05
#    ---------------- ----------------------- 4.7/11.7 MB 1.6 MB/s eta 0:00:05
#    ----------------- ---------------------- 5.2/11.7 MB 1.6 MB/s eta 0:00:05
#    ------------------- -------------------- 5.8/11.7 MB 1.7 MB/s eta 0:00:04
#    -------------------- ------------------- 6.0/11.7 MB 1.7 MB/s eta 0:00:04
#    ---------------------- ----------------- 6.6/11.7 MB 1.7 MB/s eta 0:00:04
#    ------------------------ --------------- 7.1/11.7 MB 1.7 MB/s eta 0:00:03
#    ------------------------ --------------- 7.3/11.7 MB 1.7 MB/s eta 0:00:03
#    -------------------------- ------------- 7.9/11.7 MB 1.7 MB/s eta 0:00:03
#    ---------------------------- ----------- 8.4/11.7 MB 1.8 MB/s eta 0:00:02
#    ------------------------------ --------- 8.9/11.7 MB 1.8 MB/s eta 0:00:02
#    -------------------------------- ------- 9.4/11.7 MB 1.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 10.2/11.7 MB 1.9 MB/s eta 0:00:01
#    ------------------------------------ --- 10.7/11.7 MB 1.9 MB/s eta 0:00:01
#    ------------------------------------- -- 11.0/11.7 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.7/11.7 MB 2.0 MB/s eta 0:00:00
# Downloading huggingface_hub-1.27.0-py3-none-any.whl (784 kB)
#    ---------------------------------------- 0.0/784.9 kB ? eta -:--:--
#    -------------------------- ------------- 524.3/784.9 kB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 784.9/784.9 kB 2.8 MB/s eta 0:00:00
# Downloading hf_xet-1.6.0-cp38-abi3-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/4.0 MB 3.1 MB/s eta 0:00:02
#    ------------ --------------------------- 1.3/4.0 MB 3.2 MB/s eta 0:00:01
#    ------------------ --------------------- 1.8/4.0 MB 3.3 MB/s eta 0:00:01
#    ------------------------- -------------- 2.6/4.0 MB 3.3 MB/s eta 0:00:01
#    --------------------------------- ------ 3.4/4.0 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 3.3 MB/s eta 0:00:00
# Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.7 MB 2.8 MB/s eta 0:00:01
#    ------------------- -------------------- 1.3/2.7 MB 3.4 MB/s eta 0:00:01
#    ------------------------------ --------- 2.1/2.7 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 3.6 MB/s eta 0:00:00
# Downloading filelock-3.32.2-py3-none-any.whl (98 kB)
# Downloading fsspec-2026.7.0-py3-none-any.whl (206 kB)
# Downloading safetensors-0.8.0-cp310-abi3-win_amd64.whl (355 kB)
# Downloading torch-2.13.0-cp313-cp313-win_amd64.whl (122.1 MB)
#    ---------------------------------------- 0.0/122.1 MB ? eta -:--:--
#    ---------------------------------------- 0.5/122.1 MB 3.1 MB/s eta 0:00:39
#    ---------------------------------------- 1.3/122.1 MB 3.2 MB/s eta 0:00:38
#     --------------------------------------- 2.1/122.1 MB 3.5 MB/s eta 0:00:35
#     --------------------------------------- 2.9/122.1 MB 3.6 MB/s eta 0:00:33
#    - -------------------------------------- 3.9/122.1 MB 4.0 MB/s eta 0:00:30
#    - -------------------------------------- 5.2/122.1 MB 4.3 MB/s eta 0:00:28
#    -- ------------------------------------- 6.3/122.1 MB 4.5 MB/s eta 0:00:26
#    -- ------------------------------------- 7.6/122.1 MB 4.8 MB/s eta 0:00:24
#    --- ------------------------------------ 9.2/122.1 MB 5.1 MB/s eta 0:00:23
#    --- ------------------------------------ 10.7/122.1 MB 5.3 MB/s eta 0:00:21
#    ---- ----------------------------------- 12.6/122.1 MB 5.6 MB/s eta 0:00:20
#    ---- ----------------------------------- 14.2/122.1 MB 5.8 MB/s eta 0:00:19
#    ----- ---------------------------------- 16.0/122.1 MB 6.0 MB/s eta 0:00:18
#    ----- ---------------------------------- 18.1/122.1 MB 6.3 MB/s eta 0:00:17
#    ------ --------------------------------- 20.2/122.1 MB 6.5 MB/s eta 0:00:16
#    ------- -------------------------------- 22.3/122.1 MB 6.8 MB/s eta 0:00:15
#    ------- -------------------------------- 23.6/122.1 MB 6.9 MB/s eta 0:00:15
#    -------- ------------------------------- 24.9/122.1 MB 6.8 MB/s eta 0:00:15
#    -------- ------------------------------- 25.4/122.1 MB 6.5 MB/s eta 0:00:15
#    -------- ------------------------------- 26.0/122.1 MB 6.3 MB/s eta 0:00:16
#    -------- ------------------------------- 26.5/122.1 MB 6.1 MB/s eta 0:00:16
#    -------- ------------------------------- 26.7/122.1 MB 6.0 MB/s eta 0:00:16
#    -------- ------------------------------- 27.3/122.1 MB 5.8 MB/s eta 0:00:17
#    --------- ------------------------------ 28.0/122.1 MB 5.6 MB/s eta 0:00:17
#    --------- ------------------------------ 28.6/122.1 MB 5.5 MB/s eta 0:00:17
#    --------- ------------------------------ 29.4/122.1 MB 5.4 MB/s eta 0:00:18
#    --------- ------------------------------ 29.9/122.1 MB 5.3 MB/s eta 0:00:18
#    --------- ------------------------------ 30.4/122.1 MB 5.3 MB/s eta 0:00:18
#    ---------- ----------------------------- 31.2/122.1 MB 5.2 MB/s eta 0:00:18
#    ---------- ----------------------------- 32.0/122.1 MB 5.1 MB/s eta 0:00:18
#    ---------- ----------------------------- 32.5/122.1 MB 5.0 MB/s eta 0:00:18
#    ---------- ----------------------------- 33.3/122.1 MB 5.0 MB/s eta 0:00:18
#    ----------- ---------------------------- 34.1/122.1 MB 4.9 MB/s eta 0:00:18
#    ----------- ---------------------------- 34.6/122.1 MB 4.9 MB/s eta 0:00:18
#    ----------- ---------------------------- 35.4/122.1 MB 4.8 MB/s eta 0:00:18
#    ----------- ---------------------------- 36.2/122.1 MB 4.8 MB/s eta 0:00:18
#    ------------ --------------------------- 37.0/122.1 MB 4.8 MB/s eta 0:00:18
#    ------------ --------------------------- 37.7/122.1 MB 4.8 MB/s eta 0:00:18
#    ------------ --------------------------- 38.5/122.1 MB 4.7 MB/s eta 0:00:18
#    ------------ --------------------------- 39.3/122.1 MB 4.7 MB/s eta 0:00:18
#    ------------- -------------------------- 40.1/122.1 MB 4.7 MB/s eta 0:00:18
#    ------------- -------------------------- 40.9/122.1 MB 4.7 MB/s eta 0:00:18
#    ------------- -------------------------- 41.9/122.1 MB 4.7 MB/s eta 0:00:18
#    -------------- ------------------------- 42.7/122.1 MB 4.7 MB/s eta 0:00:18
#    -------------- ------------------------- 43.8/122.1 MB 4.6 MB/s eta 0:00:17
#    -------------- ------------------------- 44.6/122.1 MB 4.6 MB/s eta 0:00:17
#    -------------- ------------------------- 45.6/122.1 MB 4.6 MB/s eta 0:00:17
#    --------------- ------------------------ 46.7/122.1 MB 4.6 MB/s eta 0:00:17
#    --------------- ------------------------ 47.2/122.1 MB 4.6 MB/s eta 0:00:17
#    --------------- ------------------------ 48.2/122.1 MB 4.6 MB/s eta 0:00:17
#    ---------------- ----------------------- 49.3/122.1 MB 4.6 MB/s eta 0:00:16
#    ---------------- ----------------------- 50.1/122.1 MB 4.6 MB/s eta 0:00:16
#    ---------------- ----------------------- 51.4/122.1 MB 4.6 MB/s eta 0:00:16
#    ----------------- ---------------------- 52.4/122.1 MB 4.6 MB/s eta 0:00:16
#    ----------------- ---------------------- 53.5/122.1 MB 4.6 MB/s eta 0:00:15
#    ----------------- ---------------------- 54.3/122.1 MB 4.6 MB/s eta 0:00:15
#    ------------------ --------------------- 55.6/122.1 MB 4.6 MB/s eta 0:00:15
#    ------------------ --------------------- 56.6/122.1 MB 4.6 MB/s eta 0:00:15
#    ------------------ --------------------- 57.4/122.1 MB 4.6 MB/s eta 0:00:14
#    ------------------- -------------------- 58.2/122.1 MB 4.6 MB/s eta 0:00:14
#    ------------------- -------------------- 59.2/122.1 MB 4.6 MB/s eta 0:00:14
#    ------------------- -------------------- 60.0/122.1 MB 4.6 MB/s eta 0:00:14
#    ------------------- -------------------- 60.8/122.1 MB 4.6 MB/s eta 0:00:14
#    -------------------- ------------------- 61.6/122.1 MB 4.6 MB/s eta 0:00:14
#    -------------------- ------------------- 62.7/122.1 MB 4.6 MB/s eta 0:00:13
#    -------------------- ------------------- 64.0/122.1 MB 4.6 MB/s eta 0:00:13
#    --------------------- ------------------ 65.0/122.1 MB 4.6 MB/s eta 0:00:13
#    --------------------- ------------------ 66.3/122.1 MB 4.6 MB/s eta 0:00:13
#    ---------------------- ----------------- 67.6/122.1 MB 4.7 MB/s eta 0:00:12
#    ---------------------- ----------------- 68.7/122.1 MB 4.7 MB/s eta 0:00:12
#    ---------------------- ----------------- 70.0/122.1 MB 4.7 MB/s eta 0:00:12
#    ----------------------- ---------------- 71.3/122.1 MB 4.7 MB/s eta 0:00:11
#    ----------------------- ---------------- 72.4/122.1 MB 4.7 MB/s eta 0:00:11
#    ------------------------ --------------- 73.4/122.1 MB 4.7 MB/s eta 0:00:11
#    ------------------------ --------------- 74.4/122.1 MB 4.7 MB/s eta 0:00:11
#    ------------------------ --------------- 75.8/122.1 MB 4.7 MB/s eta 0:00:10
#    ------------------------- -------------- 76.8/122.1 MB 4.7 MB/s eta 0:00:10
#    ------------------------- -------------- 77.9/122.1 MB 4.7 MB/s eta 0:00:10
#    ------------------------- -------------- 79.2/122.1 MB 4.8 MB/s eta 0:00:10
#    -------------------------- ------------- 80.2/122.1 MB 4.8 MB/s eta 0:00:09
#    -------------------------- ------------- 81.3/122.1 MB 4.8 MB/s eta 0:00:09
#    -------------------------- ------------- 82.3/122.1 MB 4.8 MB/s eta 0:00:09
#    --------------------------- ------------ 83.6/122.1 MB 4.8 MB/s eta 0:00:09
#    --------------------------- ------------ 84.7/122.1 MB 4.8 MB/s eta 0:00:08
#    ---------------------------- ----------- 86.0/122.1 MB 4.8 MB/s eta 0:00:08
#    ---------------------------- ----------- 87.0/122.1 MB 4.8 MB/s eta 0:00:08
#    ---------------------------- ----------- 88.1/122.1 MB 4.8 MB/s eta 0:00:08
#    ----------------------------- ---------- 88.6/122.1 MB 4.8 MB/s eta 0:00:07
#    ----------------------------- ---------- 89.4/122.1 MB 4.8 MB/s eta 0:00:07
#    ----------------------------- ---------- 89.9/122.1 MB 4.8 MB/s eta 0:00:07
#    ----------------------------- ---------- 90.7/122.1 MB 4.7 MB/s eta 0:00:07
#    ----------------------------- ---------- 91.2/122.1 MB 4.7 MB/s eta 0:00:07
#    ------------------------------ --------- 92.0/122.1 MB 4.7 MB/s eta 0:00:07
#    ------------------------------ --------- 92.8/122.1 MB 4.7 MB/s eta 0:00:07
#    ------------------------------ --------- 93.8/122.1 MB 4.7 MB/s eta 0:00:06
#    ------------------------------- -------- 94.9/122.1 MB 4.7 MB/s eta 0:00:06
#    ------------------------------- -------- 96.2/122.1 MB 4.7 MB/s eta 0:00:06
#    ------------------------------- -------- 97.3/122.1 MB 4.7 MB/s eta 0:00:06
#    -------------------------------- ------- 98.3/122.1 MB 4.7 MB/s eta 0:00:06
#    -------------------------------- ------- 99.4/122.1 MB 4.7 MB/s eta 0:00:05
#    -------------------------------- ------- 100.7/122.1 MB 4.7 MB/s eta 0:00:05
#    --------------------------------- ------ 101.7/122.1 MB 4.7 MB/s eta 0:00:05
#    --------------------------------- ------ 103.0/122.1 MB 4.8 MB/s eta 0:00:05
#    ---------------------------------- ----- 104.1/122.1 MB 4.8 MB/s eta 0:00:04
#    ---------------------------------- ----- 105.1/122.1 MB 4.8 MB/s eta 0:00:04
#    ---------------------------------- ----- 106.4/122.1 MB 4.8 MB/s eta 0:00:04
#    ----------------------------------- ---- 107.7/122.1 MB 4.8 MB/s eta 0:00:03
#    ----------------------------------- ---- 108.8/122.1 MB 4.8 MB/s eta 0:00:03
#    ------------------------------------ --- 110.1/122.1 MB 4.8 MB/s eta 0:00:03
#    ------------------------------------ --- 111.1/122.1 MB 4.8 MB/s eta 0:00:03
#    ------------------------------------ --- 112.5/122.1 MB 4.8 MB/s eta 0:00:02
#    ------------------------------------- -- 113.8/122.1 MB 4.8 MB/s eta 0:00:02
#    ------------------------------------- -- 114.8/122.1 MB 4.8 MB/s eta 0:00:02
#    -------------------------------------- - 116.1/122.1 MB 4.8 MB/s eta 0:00:02
#    -------------------------------------- - 116.7/122.1 MB 4.8 MB/s eta 0:00:02
#    -------------------------------------- - 118.0/122.1 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------  119.3/122.1 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------  120.1/122.1 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------  120.6/122.1 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------  121.4/122.1 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------  121.9/122.1 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------  121.9/122.1 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------  121.9/122.1 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 122.1/122.1 MB 4.7 MB/s eta 0:00:00
# Using cached networkx-3.6.1-py3-none-any.whl (2.1 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Downloading typer-0.27.1-py3-none-any.whl (122 kB)
# Using cached annotated_doc-0.0.5-py3-none-any.whl (5.3 kB)
# Using cached rich-15.0.0-py3-none-any.whl (310 kB)
# Using cached markdown_it_py-4.2.0-py3-none-any.whl (91 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Installing collected packages: mpmath, sympy, shellingham, safetensors, networkx, mdurl, hf-xet, fsspec, filelock, annotated-doc, torch, markdown-it-py, rich, huggingface-hub, typer, tokenizers, transformers, sentence-transformers
#
#    ----------------------------------------  0/18 [mpmath]
#    ----------------------------------------  0/18 [mpmath]
#    ----------------------------------------  0/18 [mpmath]
#    ----------------------------------------  0/18 [mpmath]
#    ----------------------------------------  0/18 [mpmath]
#    ----------------------------------------  0/18 [mpmath]
#    ----------------------------------------  0/18 [mpmath]
#    ----------------------------------------  0/18 [mpmath]
#    ----------------------------------------  0/18 [mpmath]
#    ----------------------------------------  0/18 [mpmath]
#    ----------------------------------------  0/18 [mpmath]
#    ----------------------------------------  0/18 [mpmath]
#    ----------------------------------------  0/18 [mpmath]
#    ----------------------------------------  0/18 [mpmath]
#    ----------------------------------------  0/18 [mpmath]
#    ----------------------------------------  0/18 [mpmath]
#    ----------------------------------------  0/18 [mpmath]
#    ----------------------------------------  0/18 [mpmath]
#    ----------------------------------------  0/18 [mpmath]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    ---- -----------------------------------  2/18 [shellingham]
#    ---- -----------------------------------  2/18 [shellingham]
#    ------ ---------------------------------  3/18 [safetensors]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    -------- -------------------------------  4/18 [networkx]
#    ----------- ----------------------------  5/18 [mdurl]
#    ------------- --------------------------  6/18 [hf-xet]
#    --------------- ------------------------  7/18 [fsspec]
#    --------------- ------------------------  7/18 [fsspec]
#    --------------- ------------------------  7/18 [fsspec]
#    --------------- ------------------------  7/18 [fsspec]
#    --------------- ------------------------  7/18 [fsspec]
#    --------------- ------------------------  7/18 [fsspec]
#    --------------- ------------------------  7/18 [fsspec]
#    --------------- ------------------------  7/18 [fsspec]
#    --------------- ------------------------  7/18 [fsspec]
#    --------------- ------------------------  7/18 [fsspec]
#    --------------- ------------------------  7/18 [fsspec]
#    --------------- ------------------------  7/18 [fsspec]
#    ----------------- ----------------------  8/18 [filelock]
#    ----------------- ----------------------  8/18 [filelock]
#    ----------------- ----------------------  8/18 [filelock]
#    ----------------- ----------------------  8/18 [filelock]
#    -------------------- -------------------  9/18 [annotated-doc]
#    ---------------------- ----------------- 10/18 [torch]
#    ---------------------- ----------------- 10/18 [torch]
#    ---------------------- ----------------- 10/18 [torch]
#    ---------------------- ----------------- 10/18 [torch]
#    ---------------------- ----------------- 10/18 [torch]
#    ---------------------- ----------------- 10/18 [torch]
#    ---------------------- ----------------- 10/18 [torch]
#    ---------------------- ----------------- 10/18 [torch]
#    ---------------------- ----------------- 10/18 [torch]
#    ---------------------- ----------------- 10/18 [torch]
#    ---------------------- ----------------- 10/18 [torch]
#    ---------------------- ----------------- 10/18 [torch]
#    ---------------------- ----------------- 10/18 [torch]
#    ---------------------- ----------------- 10/18 [torch]
#    ---------------------- ----------------- 10/18 [torch]
#    ---------------------- ----------------- 10/18 [torch]
#    ---------------------- ----------------- 10/18 [torch]
#    ---------------------- ----------------- 10/18 [torch]
#    ---------------------- ----------------- 10/18 [torch]
#    ---------------------- ----------------- 10/18 [torch]
#    ---------------------- ----------------- 10/18 [torch]
#    ---------------------- ----------------- 10/18 [torch]
#    ---------------------- ----------------- 10/18 [torch]
#    ---------------------- ----------------- 10/18 [torch]
#    ---------------------- ----------------- 10/18 [torch]
#    ---------------------- ----------------- 10/18 [torch]
#    ---------------------- ----------------- 10/18 [torch]
#    ---------------------- ----------------- 10/18 [torch]
#    ---------------------- ----------------- 10/18 [torch]
# ...
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ----------------------------------- ---- 16/18 [transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ------------------------------------- -- 17/18 [sentence-transformers]
#    ---------------------------------------- 18/18 [sentence-transformers]
#
# Successfully installed annotated-doc-0.0.5 filelock-3.32.2 fsspec-2026.7.0 hf-xet-1.6.0 huggingface-hub-1.27.0 markdown-it-py-4.2.0 mdurl-0.1.2 mpmath-1.3.0 networkx-3.6.1 rich-15.0.0 safetensors-0.8.0 sentence-transformers-5.7.0 shellingham-1.5.4 sympy-1.14.0 tokenizers-0.22.2 torch-2.13.0 transformers-5.15.0 typer-0.27.1
# [notice] A new release of pip is available: 25.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sentence_transformers import SentenceTransformer
import numpy as np

model = SentenceTransformer('all-MiniLM-L6-v2')

# Embed questions from train_df
question_embeddings = model.encode(
    train_df['question_clean'].tolist(),
    show_progress_bar=True,
    batch_size=64
)

print(question_embeddings.shape)  # should be (num_rows, 384)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\huggingface_hub\file_download.py:141: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Lenovo\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 90.9MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/381 [00:00<?, ?it/s]
# (24332, 384)

# %%
np.save("data/processed/text/train_question_embeddings.npy", question_embeddings)
print("Embeddings saved")
# Out:
# Embeddings saved
